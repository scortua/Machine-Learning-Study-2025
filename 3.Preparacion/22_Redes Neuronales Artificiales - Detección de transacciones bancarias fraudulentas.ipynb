# %% [markdown]
# <a href="https://colab.research.google.com/drive/1ibh29tsjCfm8xoaSnSoG5bbVRC674h32">Abre este Jupyter en Google Colab</a>

# %% [markdown]
# # Caso Práctico: Redes Neuronales Artificiales (RNA)

# %% [markdown]
# ## Conjunto de datos: Detección de transacciones bancarias fraudulentas

# %% [markdown]
# ### Descripción
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.
#
# ### Descarga de los ficheros de datos
# https://www.kaggle.com/mlg-ulb/creditcardfraud#creditcard.csv
#
# ### Referencias adicionales sobre el conjunto de datos
# _The dataset has been collected and analysed during a research collaboration of Worldline and the Machine Learning Group (http://mlg.ulb.ac.be) of ULB (Université Libre de Bruxelles) on big data mining and fraud detection.
# More details on current and past projects on related topics are available on https://www.researchgate.net/project/Fraud-detection-5 and the page of the DefeatFraud project._

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.gridspec as gridspec
from collections import Counter
from sklearn import metrics
import numpy as np
from sklearn.model_selection import train_test_split
from matplotlib.colors import LogNorm
from sklearn.metrics import f1_score

# %% [markdown]
# ## Funciones auxiliares

# %%
# Construcción de una función que realice el particionado completo
def train_val_test_split(df, rstate=42, shuffle=True, stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.4, random_state=rstate, shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate, shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
def remove_labels(df, label_name):
    X = df.drop(label_name, axis=1)
    y = df[label_name].copy()
    return (X, y)

# %% [markdown]
# ## 1. Lectura del conjunto de datos

# %%
df = pd.read_csv("datasets/creditcard.csv")

# %% [markdown]
# ## 2. Visualización del conjunto de datos

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
print("Número de características:", len(df.columns))
print("Longitud del conjunto de datos:", len(df))
# Out:
# Número de características: 31
# Longitud del conjunto de datos: 284807

# %%
# 492 transacciones fraudulentas, 284315 transacciones legitimas
# El conjunto de datos se encuntra desequilabrado
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Visualizamos los tipos de cada uno de los atributos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# Comprobamos si alguna columna tiene valores nulos
df.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.628620e-16 -3.576577e-16  2.618565e-16  4.473914e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.109395e-16  1.686100e-15 -3.661401e-16 -1.227452e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
# Representación gráfica de dos características
plt.figure(figsize=(14, 6))
plt.scatter(df["V10"][df['Class'] == 0], df["V14"][df['Class'] == 0], c="g", marker=".")
plt.scatter(df["V10"][df['Class'] == 1], df["V14"][df['Class'] == 1], c="r", marker=".")
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %% [markdown]
# ## 3. Preparación del conjunto de datos

# %% [markdown]
# Para este tipo de algoritmos es importante que todos los datos se encuentren en un rango similar, por lo tanto, podemos aplicar una función de escalado o normalización. Otra opción, es eliminar las características que no se encuentran en un rango similar siempre y cuando no sean muy influyentes para la predicción.

# %%
df = df.drop(["Time", "Amount"], axis=1)

# %% [markdown]
# ## 4. División del conjunto de datos

# %%
# Dividimos el conjunto de datos
train_set, val_set, test_set = train_val_test_split(df)

# %%
X_train, y_train = remove_labels(train_set, 'Class')
X_val, y_val = remove_labels(val_set, 'Class')
X_test, y_test = remove_labels(test_set, 'Class')

# %% [markdown]
# ## 5. Redes Neuronales Artificiales con un conjunto de datos de dos dimensiones

# %% [markdown]
# Antes de comenzar con la detección de transacciones fraudulentas mediante Redes Neuronales Artificiales para todos los atributos del conjunto de datos, se realiza una prueba para dos atributos con el objetivo de comprender como construye el límite de decisión.

# %%
X_train_reduced = X_train[["V10", "V14"]].copy()
X_val_reduced = X_val[["V10", "V14"]].copy()
X_test_reduced = X_test[["V10", "V14"]].copy()

# %%
X_train_reduced
# Out:
#              V10       V14
# 164406 -0.975273 -0.115675
# 220383  0.919355 -0.505054
# 49922  -0.094516 -0.439746
# 181642  0.107004  0.565399
# 210715 -0.179247 -0.433966
# ...          ...       ...
# 119879  0.079128  0.600937
# 259178 -0.654029  0.384625
# 131932 -0.212753 -0.019493
# 146867 -0.027572  0.927786
# 121958  0.543016 -0.346209
#
# [170884 rows x 2 columns]

# %% [markdown]
# **Entrenamiento del algoritmo con un conjunto de datos reducido**

# %%
# Instalamos tensorflow
# !pip install tensorflow
# !pip install keras
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.74.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorflow) (2.3.3)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow)
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.17.0-cp313-cp313-win_amd64.whl.metadata (34 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#     --------------------------------------- 6.8/332.0 MB 38.4 MB/s eta 0:00:09
#    -- ------------------------------------- 17.0/332.0 MB 43.4 MB/s eta 0:00:08
#    --- ------------------------------------ 28.3/332.0 MB 46.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 40.1/332.0 MB 49.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 49.3/332.0 MB 48.7 MB/s eta 0:00:06
#    ------- -------------------------------- 61.9/332.0 MB 49.1 MB/s eta 0:00:06
#    -------- ------------------------------- 73.4/332.0 MB 49.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 86.2/332.0 MB 50.6 MB/s eta 0:00:05
#    ----------- ---------------------------- 99.4/332.0 MB 51.5 MB/s eta 0:00:05
#    ------------- ------------------------- 111.7/332.0 MB 52.1 MB/s eta 0:00:05
#    -------------- ------------------------ 120.8/332.0 MB 51.3 MB/s eta 0:00:05
#    --------------- ----------------------- 132.4/332.0 MB 51.9 MB/s eta 0:00:04
#    ---------------- ---------------------- 143.9/332.0 MB 51.6 MB/s eta 0:00:04
#    ------------------ -------------------- 157.5/332.0 MB 52.0 MB/s eta 0:00:04
#    ------------------- ------------------- 168.6/332.0 MB 52.0 MB/s eta 0:00:04
#    -------------------- ------------------ 172.5/332.0 MB 49.8 MB/s eta 0:00:04
#    --------------------- ----------------- 184.3/332.0 MB 50.1 MB/s eta 0:00:03
#    ---------------------- ---------------- 195.0/332.0 MB 50.1 MB/s eta 0:00:03
#    ------------------------ -------------- 208.7/332.0 MB 50.7 MB/s eta 0:00:03
#    ------------------------- ------------- 220.2/332.0 MB 50.8 MB/s eta 0:00:03
#    --------------------------- ----------- 232.0/332.0 MB 51.0 MB/s eta 0:00:02
#    ---------------------------- ---------- 242.7/332.0 MB 51.0 MB/s eta 0:00:02
#    ----------------------------- --------- 254.5/332.0 MB 51.2 MB/s eta 0:00:02
#    ------------------------------- ------- 265.8/332.0 MB 51.8 MB/s eta 0:00:02
#    -------------------------------- ------ 276.8/332.0 MB 52.0 MB/s eta 0:00:02
#    --------------------------------- ----- 287.8/332.0 MB 51.9 MB/s eta 0:00:01
#    ----------------------------------- --- 300.7/332.0 MB 52.0 MB/s eta 0:00:01
#    ------------------------------------ -- 314.0/332.0 MB 53.0 MB/s eta 0:00:01
#    --------------------------------------  326.1/332.0 MB 53.0 MB/s eta 0:00:01
#    --------------------------------------  331.9/332.0 MB 53.0 MB/s eta 0:00:01
#    --------------------------------------  331.9/332.0 MB 53.0 MB/s eta 0:00:01
#    --------------------------------------  331.9/332.0 MB 53.0 MB/s eta 0:00:01
#    ---------------------------------------- 332.0/332.0 MB 46.9 MB/s  0:00:07
# Downloading grpcio-1.74.0-cp313-cp313-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------------- 4.5/4.5 MB 57.1 MB/s  0:00:00
# Downloading ml_dtypes-0.5.3-cp313-cp313-win_amd64.whl (208 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl (107 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 5.5/5.5 MB 53.1 MB/s  0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 28.1 MB/s  0:00:00
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 28.5 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ----------- ---------------------------- 7.6/26.4 MB 36.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.9/26.4 MB 44.8 MB/s eta 0:00:01
#    ---------------------------------------  26.2/26.4 MB 42.8 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 39.5 MB/s  0:00:00
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.32.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading wrapt-1.17.3-cp313-cp313-win_amd64.whl (38 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp313-cp313-win_amd64.whl (316 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, urllib3, termcolor, tensorboard-data-server, protobuf, optree, opt_einsum, ml_dtypes, mdurl, MarkupSafe, markdown, idna, h5py, grpcio, google_pasta, gast, charset_normalizer, certifi, astunparse, absl-py, werkzeug, requests, markdown-it-py, tensorboard, rich, keras, tensorflow
#
#    - --------------------------------------  1/30 [libclang]
#    - --------------------------------------  1/30 [libclang]
#    - --------------------------------------  1/30 [libclang]
#    -- -------------------------------------  2/30 [flatbuffers]
#    ---- -----------------------------------  3/30 [wrapt]
#    ---- -----------------------------------  3/30 [wrapt]
#    ----- ----------------------------------  4/30 [urllib3]
#    ----- ----------------------------------  4/30 [urllib3]
#    ----- ----------------------------------  4/30 [urllib3]
#    ----- ----------------------------------  4/30 [urllib3]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    --------- ------------------------------  7/30 [protobuf]
#    ---------- -----------------------------  8/30 [optree]
#    ---------- -----------------------------  8/30 [optree]
#    ---------- -----------------------------  8/30 [optree]
#    ------------ ---------------------------  9/30 [opt_einsum]
#    ------------ ---------------------------  9/30 [opt_einsum]
#    ------------ ---------------------------  9/30 [opt_einsum]
#    -------------- ------------------------- 11/30 [mdurl]
#    ----------------- ---------------------- 13/30 [markdown]
#    ----------------- ---------------------- 13/30 [markdown]
#    ----------------- ---------------------- 13/30 [markdown]
#    ----------------- ---------------------- 13/30 [markdown]
#    ----------------- ---------------------- 13/30 [markdown]
#    ----------------- ---------------------- 13/30 [markdown]
#    ------------------ --------------------- 14/30 [idna]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    -------------------- ------------------- 15/30 [h5py]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    --------------------- ------------------ 16/30 [grpcio]
#    ---------------------- ----------------- 17/30 [google_pasta]
#    ---------------------- ----------------- 17/30 [google_pasta]
#    ---------------------- ----------------- 17/30 [google_pasta]
#    ---------------------- ----------------- 17/30 [google_pasta]
#    ------------------------ --------------- 18/30 [gast]
#    ------------------------- -------------- 19/30 [charset_normalizer]
#    ------------------------- -------------- 19/30 [charset_normalizer]
#    -------------------------- ------------- 20/30 [certifi]
#    ----------------------------- ---------- 22/30 [absl-py]
#    ----------------------------- ---------- 22/30 [absl-py]
#    ----------------------------- ---------- 22/30 [absl-py]
#    ----------------------------- ---------- 22/30 [absl-py]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    ------------------------------ --------- 23/30 [werkzeug]
#    -------------------------------- ------- 24/30 [requests]
#    -------------------------------- ------- 24/30 [requests]
#    -------------------------------- ------- 24/30 [requests]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    --------------------------------- ------ 25/30 [markdown-it-py]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ---------------------------------- ----- 26/30 [tensorboard]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------ --- 27/30 [rich]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    ------------------------------------- -- 28/30 [keras]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    -------------------------------------- - 29/30 [tensorflow]
#    ---------------------------------------- 30/30 [tensorflow]
#
# Successfully installed MarkupSafe-3.0.2 absl-py-2.3.1 astunparse-1.6.3 certifi-2025.8.3 charset_normalizer-3.4.3 flatbuffers-25.2.10 gast-0.6.0 google_pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 idna-3.10 keras-3.11.3 libclang-18.1.1 markdown-3.9 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 protobuf-6.32.1 requests-2.32.5 rich-14.1.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 urllib3-2.5.0 werkzeug-3.1.3 wrapt-1.17.3
# Requirement already satisfied: keras in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (3.11.3)
# Requirement already satisfied: absl-py in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (2.3.3)
# Requirement already satisfied: rich in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (14.1.0)
# Requirement already satisfied: namex in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (0.17.0)
# Requirement already satisfied: ml-dtypes in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (0.5.3)
# Requirement already satisfied: packaging in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in s:\software\anacona\envs\ibmmachienlearning\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# Definición de la arquitectura de la red neuronal
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(X_train_reduced.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
             loss='binary_crossentropy',
             metrics=['acc'])
# Out:
# s:\SOFTWARE\ANACONA\envs\IBMmachienlearning\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Resumen de las capas del modelo
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,265 (44.00 KB)
#  Trainable params: 11,265 (44.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrenamos el modelo
history = model.fit(X_train_reduced,
                   y_train,
                   epochs=40,
                   batch_size=512,
                   validation_data=(X_val_reduced, y_val))
# Out:
# Epoch 1/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - acc: 0.9970 - loss: 0.0374 - val_acc: 0.9991 - val_loss: 0.0046
# Epoch 2/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9992 - loss: 0.0043 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 3/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9992 - loss: 0.0040 - val_acc: 0.9992 - val_loss: 0.0039
# Epoch 4/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9992 - loss: 0.0039 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 5/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9992 - loss: 0.0039 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 6/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9993 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 7/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9992 - loss: 0.0038 - val_acc: 0.9993 - val_loss: 0.0036
# Epoch 8/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9992 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 9/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 10/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9992 - loss: 0.0037 - val_acc: 0.9993 - val_loss: 0.0035
# Epoch 11/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9992 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 12/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 13/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9993 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 14/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9993 - loss: 0.0038 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 15/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 16/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9993 - val_loss: 0.0038
# Epoch 17/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 18/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 19/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0036
# Epoch 20/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0042
# Epoch 21/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 22/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9992 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 23/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9993 - val_loss: 0.0037
# Epoch 24/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9992 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 25/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0036
# Epoch 26/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 27/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 28/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0040
# Epoch 29/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 30/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9993 - val_loss: 0.0038
# Epoch 31/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 32/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 33/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 34/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 35/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 36/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 37/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - acc: 0.9993 - loss: 0.0037 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 38/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - acc: 0.9993 - loss: 0.0036 - val_acc: 0.9994 - val_loss: 0.0036
# Epoch 39/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - acc: 0.9993 - loss: 0.0036 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 40/40
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.9993 - loss: 0.0036 - val_acc: 0.9994 - val_loss: 0.0036

# %% [markdown]
# **Representación del límite de decisión**

# %%
def plot_ann_decision_boundary(X, y, model, steps=1000):
    xmin, xmax = X[:,0].min() - 1, X[:,0].max() + 1
    ymin, ymax = X[:,1].min() - 1, X[:,1].max() + 1
    steps = 1000
    
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = labels.reshape(xx.shape)
    
    plt.contourf(xx, yy, Z, cmap="RdBu", alpha=0.5)
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], 'k.', markersize=2)
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], 'r.', markersize=2)

# %%
plt.figure(figsize=(14, 6))
plot_ann_decision_boundary(X_train_reduced.values, y_train, model)
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step

# %% [markdown]
# **Representación de los ejemplos catalogados como maliciosos**

# %%
# Predicción con el conjunto de datos de entrenamiento
pred = model.predict(X_train_reduced) 
y_pred = (pred > 0.5).astype("int32")
# Out:
# 5341/5341 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step

# %%
plt.figure(figsize=(14, 6))
plt.plot(X_train_reduced[y_pred==1]["V10"], X_train_reduced[y_pred==1]["V14"], 'go', markersize=4)
plot_ann_decision_boundary(X_train_reduced.values, y_train, model)
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()
# Out:
# 31250/31250 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step

# %% [markdown]
# **Predicción con el conjunto de datos reducido**

# %%
# Predicción con el conjunto de datos de pruebas
pred = model.predict(X_test_reduced) 
y_pred = (pred > 0.5).astype("int32")
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# F1 Score: 0.7976878612716763

# %% [markdown]
# ## 6. Redes Neuronales Artificiales con un conjunto de datos multidimensional

# %% [markdown]
# ### Aplicamos selección de características con Random Forest

# %%
# Utilizamos Random Forest para realizar selección de características
from sklearn.ensemble import RandomForestClassifier

clf_rnd = RandomForestClassifier(n_estimators=50, random_state=42, n_jobs=-1)
clf_rnd.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, n_jobs=-1, random_state=42)

# %%
# Seleccionamos las características más importantes
feature_importances = {name: score for name, score in zip(list(X_train), clf_rnd.feature_importances_)}
feature_importances_sorted = pd.Series(feature_importances).sort_values(ascending=False)
feature_importances_sorted.head(10)
# Out:
# V17    0.243018
# V14    0.132483
# V12    0.093261
# V11    0.066525
# V16    0.066489
# V10    0.058905
# V18    0.034265
# V9     0.030203
# V4     0.025529
# V7     0.021010
# dtype: float64

# %%
# Reducimos el conjunto de datos a las 20 características más importantes
features = list(feature_importances_sorted.head(20).index)
X_train_select = X_train[features].copy()
X_val_select = X_val[features].copy()
X_test_select = X_test[features].copy()
X_train_select
# Out:
#              V17       V14       V12       V11       V16       V10       V18  \
# 164406 -1.209313 -0.115675 -0.589246 -1.850664  0.954582 -0.975273  0.640636
# 220383 -0.685169 -0.505054 -0.440400 -0.752344  0.794032  0.919355 -0.031408
# 49922  -1.121411 -0.439746 -0.361721 -0.942655  1.077567 -0.094516  0.342143
# 181642 -0.107078  0.565399 -0.035721 -1.144233 -0.494280  0.107004 -0.658594
# 210715  0.349047 -0.433966  0.355078  1.124602  0.505890 -0.179247  0.251416
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879 -0.356782  0.600937  0.777009  1.585195  0.239566  0.079128 -0.410923
# 259178 -0.462528  0.384625  0.346437 -0.421422  0.057999 -0.654029 -0.063197
# 131932 -0.539887 -0.019493  0.022804 -0.382362 -0.144778 -0.212753 -0.068375
# 146867 -0.396148  0.927786  0.570400 -0.418939  0.426113 -0.027572 -0.946837
# 121958 -0.040565 -0.346209 -0.407529 -0.546288  1.447832  0.543016 -1.314021
#
#               V9        V4        V7        V1       V15       V20        V6  \
# 164406  0.226930 -0.779271  0.176700 -1.509348  0.337068  0.502244 -0.250687
# 220383 -0.965050  2.972199  0.497715 -0.855208 -0.981423 -0.358988  0.195791
# 49922  -0.612186  0.455518 -0.402337 -1.082417 -0.652224 -0.028980  4.381102
# 181642  0.450298  0.672408  0.612810  1.898722 -0.368894 -0.082106 -1.267347
# 210715  0.375881  0.354859  0.016307  2.019857 -0.397238 -0.218017 -0.688151
# ...          ...       ...       ...       ...       ...       ...       ...
# 119879 -0.114199  0.461596 -0.165254  1.173488  0.658885 -0.157534 -0.213165
# 259178  0.400697 -1.241113 -0.466107 -0.775981  0.785702 -0.295730  3.912076
# 131932 -0.491303  0.485774  1.076640 -0.146609  0.690200  0.007155 -0.815198
# 146867  0.580199 -3.798905 -0.471769 -2.948638 -0.090065  0.417396  2.727695
# 121958 -0.749637 -0.698559 -0.502369  1.233174  0.893667  0.337732 -0.637028
#
#              V21        V3       V26        V8       V27        V5
# 164406  0.369591  1.089287  0.288080  0.211197 -0.023211  1.213151
# 220383  1.074965  2.563111 -0.011914 -0.915033 -0.087454 -0.187680
# 49922  -0.069963  1.375652 -0.119972  1.227511 -0.072594  2.471959
# 181642  0.015111 -1.771837  0.378225 -0.441070 -0.106042  0.115019
# 210715 -0.312851 -1.623959  0.146084 -0.043346 -0.072767  0.291940
# ...          ...       ...       ...       ...       ...       ...
# 119879 -0.186027  0.490512  0.109235  0.119221 -0.020922 -0.296377
# 259178  0.037078 -1.142399 -0.770941  1.360620  0.066006  1.940358
# 131932  0.052649  1.524591 -0.398467 -0.395316 -0.121139  0.349308
# 146867 -0.332759 -2.521201  0.426309  2.217537  0.496912  1.866302
# 121958  0.027634  0.386784 -0.393074 -0.188057  0.001217 -1.034018
#
# [170884 rows x 20 columns]

# %% [markdown]
# ### Entrenamiento del algoritmo RNA

# %%
# Entrenamiento del algoritmo
model = models.Sequential()

model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(X_train_select.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['acc'])
# Out:
# s:\SOFTWARE\ANACONA\envs\IBMmachienlearning\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 128)            │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,569 (53.00 KB)
#  Trainable params: 13,569 (53.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrenamos el algoritmo
history = model.fit(X_train_select,
                   y_train,
                   epochs=10,
                   batch_size=64,
                   validation_data=(X_val_select, y_val))
# Out:
# Epoch 1/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - acc: 0.9989 - loss: 0.0087 - val_acc: 0.9994 - val_loss: 0.0036
# Epoch 2/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - acc: 0.9994 - loss: 0.0034 - val_acc: 0.9994 - val_loss: 0.0033
# Epoch 3/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - acc: 0.9994 - loss: 0.0031 - val_acc: 0.9994 - val_loss: 0.0042
# Epoch 4/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - acc: 0.9994 - loss: 0.0030 - val_acc: 0.9994 - val_loss: 0.0035
# Epoch 5/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - acc: 0.9994 - loss: 0.0029 - val_acc: 0.9994 - val_loss: 0.0032
# Epoch 6/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - acc: 0.9994 - loss: 0.0027 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 7/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - acc: 0.9994 - loss: 0.0026 - val_acc: 0.9993 - val_loss: 0.0040
# Epoch 8/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - acc: 0.9994 - loss: 0.0025 - val_acc: 0.9994 - val_loss: 0.0034
# Epoch 9/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - acc: 0.9994 - loss: 0.0023 - val_acc: 0.9994 - val_loss: 0.0033
# Epoch 10/10
# 2671/2671 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - acc: 0.9994 - loss: 0.0022 - val_acc: 0.9993 - val_loss: 0.0034

# %%
# Predicción con el conjunto de datos de pruebas
pred = model.predict(X_test_select) 
y_pred = (pred > 0.5).astype("int32")
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# F1 Score: 0.8191489361702128
